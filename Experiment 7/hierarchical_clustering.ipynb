# %% [markdown]
# <a href="https://colab.research.google.com/github/archajoshy/Advanced-Computing-Lab/blob/main/Experiment%207/hierarchical_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data=pd.read_csv('/content/iris.csv')
x=data[['sepal.length',	'sepal.width',	'petal.length',	'petal.width']]
x=x[:50]

# %%
from sklearn.decomposition import PCA
pca=PCA(n_components=2)

# %%
pca=pca.fit_transform(x)

# %%
df=pd.DataFrame(pca,columns=['PC1','PC2'])
df
# Out:
#          PC1       PC2
# 0   0.106842  0.024894
# 1  -0.394047 -0.165866
# 2  -0.390688  0.126851
# 3  -0.511702  0.026561
# 4   0.113349  0.146750
# 5   0.642901 -0.079406
# 6  -0.294755  0.248675
# 7  -0.023826 -0.026391
# 8  -0.802001  0.071009
# 9  -0.317334 -0.139710
# 10  0.464050 -0.079342
# 11 -0.147987  0.044181
# 12 -0.467311 -0.092984
# 13 -0.830814  0.352975
# 14  0.922962  0.014723
# 15  1.191390  0.149577
# 16  0.604283  0.116616
# 17  0.113199  0.011800
# 18  0.763853 -0.307745
# 19  0.343097  0.148997
# 20  0.263114 -0.363555
# 21  0.276039  0.073836
# 22 -0.192900  0.581926
# 23  0.008045 -0.285539
# 24 -0.119024 -0.102836
# 25 -0.307831 -0.323665
# 26 -0.001459 -0.101584
# 27  0.183405 -0.083900
# 28  0.100335 -0.096962
# 29 -0.361725 -0.020166
# 30 -0.368232 -0.142021
# 31  0.256518 -0.291732
# 32  0.617537  0.301598
# 33  0.888377  0.220212
# 34 -0.310978 -0.152804
# 35 -0.199619 -0.003509
# 36  0.364819 -0.165254
# 37  0.040085  0.219632
# 38 -0.738241  0.182082
# ...

# %%
from scipy.cluster import hierarchy
import matplotlib.pyplot as plt
Y=hierarchy.linkage(df,'average')
plt.figure(figsize=(15,10))
fig = hierarchy.dendrogram(Y,above_threshold_color='orange', orientation='top')
plt.show()

# %%
data_1=pd.read_csv('/content/basic4.csv')
x=data_1[['x',	'y']]
x=x[:100]

# %%
xaxis=data_1['x']
yaxis=data_1['y']
plt.scatter(xaxis,yaxis)

# %%
Y_1=hierarchy.linkage(x,'average')
plt.figure(figsize=(15,10))
fig_1 = hierarchy.dendrogram(Y_1,above_threshold_color='orange', orientation='top')
plt.show()
